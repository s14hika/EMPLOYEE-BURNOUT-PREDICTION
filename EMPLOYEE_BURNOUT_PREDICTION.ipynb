# %% [markdown]
# <a href="https://colab.research.google.com/github/s14hika/EMPLOYEE-BURNOUT-PREDICTION/blob/main/EMPLOYEE_BURNOUT_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the new CSV file
file_path = '/content/sample_submission.csv'
data = pd.read_csv(file_path)

# Generate descriptive statistics
descriptive_stats = data['Burn Rate'].describe()
print("Descriptive Statistics:\n", descriptive_stats)

# Visualize the burn rates
plt.figure(figsize=(10, 6))
sns.histplot(data['Burn Rate'], bins=10, kde=True)
plt.title('Distribution of Burn Rates')
plt.xlabel('Burn Rate')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x=data['Burn Rate'])
plt.title('Box Plot of Burn Rates')
plt.xlabel('Burn Rate')
plt.show()
# Out:
# Descriptive Statistics:
#  count    5.000000
# mean     0.346000
# std      0.163646
# min      0.160000
# 25%      0.200000
# 50%      0.360000
# 75%      0.490000
# max      0.520000
# Name: Burn Rate, dtype: float64
